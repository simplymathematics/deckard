# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('cifar100/cifar100/reports/clean_attack.csv', index_col=0)

# %%
# ! cd ../../ && python -m pip install -e .

# %%
from deckard.layers.clean_data import pareto_set

sense_dict = {
    "accuracy" : "max",
    "adv_accuracy" : "max",
    # "atk_gen": "diff",
    "def_value": "diff",
    "def_gen": "diff",
    "data.sample.random_state": "diff",
    # "train_time" : "min",
    # "predict_time" : "min",
    # "model_layers"  : "diff",
}
pareto = pareto_set(df, sense_dict)
pareto.shape
# Out:
# (718, 233)

# %%
sns.lineplot(data=pareto, x="def_value", y="accuracy", hue="def_gen", errorbar='se', err_style='bars')
# Out:
# <Axes: xlabel='def_value', ylabel='accuracy'>
